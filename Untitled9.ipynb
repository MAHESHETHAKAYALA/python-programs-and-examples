# %%
x="we are good in python"
y=x.split()
print(y)
# Out:
# ['we', 'are', 'good', 'in', 'python']

# %%
list1=int(input('enter a num'))
list2=20
list3=10
list4=35
if list2>=list4:
  print('positive num')
elif  list3<=list2:
  print('negative num')
else:
  print('zero')
# Out:
# enter a num10
# negative num

# %%
list1=[1,2,3,4,5]
list1.append([10,20,30])
print(list1)
# Out:
# [1, 2, 3, 4, 5, [10, 20, 30]]

# %%
list1=(60)
listt2=(30)
if list1<=list2:
  print('short num')
else:
  print('large num')
# Out:
# large num

# %%
a=(34,88,-89)
x=min(a)
print(x)
# Out:
# -89

# %%
list1=[20,45,89]
d=max(list1)
print(d)
# Out:
# 89

# %%
cap='HeLlO SiVa'
ram=cap.capitalize()
print(ram)
# Out:
# Hello siva

# %%
systems=['window','shadow','sun']
print('original list:',systems)
systems.reverse()
print('updated list:',systems)
# Out:
# original list: ['window', 'shadow', 'sun']
# updated list: ['sun', 'shadow', 'window']

# %%
prime_numbers=[2,5,3,6]
numbers=[10,20]
numbers.extend(prime_numbers)
print('list after.extend:',numbers)
# Out:
# list after.extend: [10, 20, 2, 5, 3, 6]

# %%
var=['mango','potato','sweet','grapes']
split=var.pop(0)
print(split)
# Out:
# mango

# %%
for i in var:
  if i.isalpha():
    print(i)
# Out:
# potato
# sweet
# grapes

# %%
product=1
for i in list:
     product=product*1
return product
list1=[10,45,20]
print(list1)
print("product:")
print(mul_list(list1))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-57-bfa16514ee82> in <cell line: 2>()
#       1 product=1
# ----> 2 for i in list:
#       3      product=product*1
#       4 return product
#       5 list1=[10,45,20]
#
# TypeError: 'type' object is not iterable
