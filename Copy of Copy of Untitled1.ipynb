# %%
num=int(input())
num1=int(input())
if(num>=num1):
  print('num is biggr than num1')
else:
  print('num1 is biggar than num')
# Out:
# 654
# 21
# num is biggr than num1

# %%
quantity=int(input())
totalcost=quantity*100
print(totalcost)
if(totalcost>=1000):
  discountprice=totalcost-totalcost*0.1
print(discountprice)
# Out:
# 15
# 1500
# 1350.0

# %%
marks=int(input('enter ur marks'))
if(marks<=25):
  print('student grade is E')
elif(marks>=25 and marks<=45):
  print('student grade is D')
elif(marks>=45 and marks<=50):
  print('student grade is C')
elif(marks>=50 and marks<=60):
  print('student grade is B')
elif(marks>=60 and marks<=80):
  print('student grade is A')
else:
  print('Topper')
# Out:
# enter ur marks95
# Topper
