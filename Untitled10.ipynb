# %%
l=[1,2,3,4]
a=iter(l)
print(next(a))
# Out:
# 1

# %%
a=map(lambda a:a+10,[1,2,3])
print(a)
print(set(a))
# Out:
# ...
# {11, 12, 13}

# %%
def mult_yield():
  str1="siva"
  yield str1
  str2="mahesh"
  yield str2
  str3="sai vamsi sree ram prasad"
  yield str3
x=mult_yield()
print(next(x))
print(next(x))
print(next(x))
# Out:
# siva
# mahesh
# sai vamsi sree ram prasad

# %%
import pickle
siva=[10,20,30]
with open("datafile.txt","wb") as a:
     pickle.dump(siva,a)

# %%
import pickle
pickle_and=open("datafile.txt","rb")
emp=pickle.load(pickle_and)
print(emp)
# Out:
# [10, 20, 30]

# %%
A=10
def fun():
    a=100+A
    b=500+A
print(a,b,A)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-43-588e11780671> in <cell line: 5>()
#       3     a=100+A
#       4     b=500+A
# ----> 5 print(a,b,A)
#       6
#
# NameError: name 'b' is not defined
