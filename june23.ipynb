# %%
num=int(input('enter a numerical value '))
if(num>0):
  print('it is a positive number')
elif(num<0):
  print('it is a negative number')
else:
  print('it is a zero')
# Out:
# enter a numerical value -1
# it is a negative number

# %%
age=int(input('enter your age'))
if(age>=18):
  print('your eligible vote')
else:
  print('you are not eligible vote')
# Out:
# enter your age10
# you are not eligible vote

# %%
num1=int(input())
num2=int(input())
num3=int(input())
if(num1>num2 and num1>num3):
  print(num1)
elif(num2>num1 and num2>num3):
  print(num2)
else:
  print(num3)
# Out:
# 7
# 2
# 9
# 9

# %%
year=int(input())
if(year%100==0 and year%400==0):
  print('leap year')
elif(year%4==0 and year%100!=0):
  print('leap year')
else:
  print('not a leap year')
# Out:
# 2028
# leap year

# %%
tempC=int(input('enter temparature in celsius : '))
if(tempC>0):
  fahrenheit=(tempC*9/5)+32
  print(fahrenheit)
else:
  kelvin=273.15+tempC
  print(kelvin)
# Out:
# enter temparature in celsius : 6
# 42.8

# %%
pal=input()
for i in pal:
  reversed=pal[::-1]
print(reversed)

if(pal==reversed):
  print('it is a pallindrome')
else:
  print('not A pallindrome')
# Out:
# madam
# madam
# it is a pallindrome

# %%
age=int(input('enter your age '))
weight=int(input('enter your weight '))
if(age>=18):
  if(weight>=55):
    print('your eligible to donate blood')
  else:
    print('your above 18 but you have less weight so ur not eligible give blood')
else:
  print('youre age is lessthan 18 so ur not eligible to donate blood')
# Out:
# enter your age 12
# enter your weight 22
# youre age is lessthan 18 so ur not eligible to donate blood
